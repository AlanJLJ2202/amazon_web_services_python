# %%
import boto3
import pandas as pd
from io import StringIO, BytesIO
from datetime import datetime, timedelta

# %%
# Adapter Layer

def read_csv_to_df():
    pass

def write_df_to_s3():
    pass

def return_objects():
    pass

# %%
# Application Layer

def extract():
    pass

def transform_report():
    pass

def load():
    pass

def etl_report():
    pass

# %%
# main function entrypoint

def main():
    # Parameters/Configurations    
    
    # Init    
    
    # run application

# %%
# run

main()

# %% [markdown]
# ## Reading the uploaded file

# %%
trg_bucket = 'xetra-bucket-12345'
s3 = boto3.resource('s3')
bucket_trg = s3.Bucket(trg_bucket)
for obj in bucket_trg.objects.all():
    print(obj.key)
# Out:
# xetra_daily_report_20220215_115050.parquet
# xetra_daily_report_20220218_134804.parquet
# xetra_daily_report_20220308_103748.parquet
# xetra_daily_report_20220310_110626.parquet

# %%
prq_obj = bucket_trg.Object(key='xetra_daily_report_20220310_110626.parquet').get().get('Body').read()
data = BytesIO(prq_obj)
df_report = pd.read_parquet(data)

# %%
df_report
# Out:
#               ISIN        Date  opening_price_eur  closing_price_eur  \
# 0     AT000000STR1  2022-03-10              35.85              35.85
# 1     AT00000FACC2  2022-03-10               7.41               7.35
# 2     AT0000606306  2022-03-10              14.13              13.11
# 3     AT0000609607  2022-03-10              11.00              11.00
# 4     AT0000644505  2022-03-10              96.50              89.90
# ...            ...         ...                ...                ...
# 3219  XS2427363036  2022-03-10              20.17              20.17
# 3220  XS2427363895  2022-03-10              17.27              17.27
# 3221  XS2427474023  2022-03-10              23.19              23.24
# 3222  XS2434891219  2022-03-10               3.55               3.55
# 3223  XS2437455608  2022-03-10              28.92              28.92
#
#       minimum_price_eur  maximum_price_eur  daily_traded_volume  \
# 0                 35.85              35.85                    0
# 1                  7.35               7.41                  200
# 2                 12.80              14.13                64103
# 3                 11.00              11.00                    0
# 4                 88.10              96.60                  794
# ...                 ...                ...                  ...
# 3219              20.17              20.17                    0
# 3220              17.27              17.27                    0
# 3221              23.19              23.24                  130
# 3222               3.54               3.59               101700
# 3223              28.92              28.92                    0
#
#       change_prev_closing_%
# 0                     -1.65
# 1                     -0.68
# 2                     -4.59
# 3                     -1.79
# 4                     -3.64
# ...                     ...
# 3219                   1.35
# 3220                  -5.49
# 3221                   2.41
# 3222                  -7.33
# 3223                  -3.14
#
# [3224 rows x 8 columns]
